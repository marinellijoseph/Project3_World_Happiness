# %%
# import dependencies
import os, glob
import pandas as pd

# %%
# combine csvs then write to combined csv
#path =r'Data/NYT Articles' # for main 4 countries
path =r'Data/NYT Articles/other countries' # for other countries to test nlp model
all_files = glob.glob(os.path.join(path, "*.csv"))
NYT_Articles_combined = pd.concat((pd.read_csv(f) for f in all_files))

NYT_Articles_combined = NYT_Articles_combined[['Country','Snippets']]
NYT_Articles_combined = NYT_Articles_combined
NYT_Articles_combined['Country'].unique()
# Out:
# array(['benin', 'brazil', 'canada', 'bhutan', 'lithuania', 'cambodia',
#        'montenegro', 'saudi_arabia', 'kenya', 'libya'], dtype=object)

# %%
# map class column and happy or unhappy values to countries
country_class = {'benin': 'unhappy', 'brazil': 'happy', 'canada': 'happy', 'bhutan': 'unhappy', 'lithuania': 'happy', 
                 'cambodia': 'unhappy','montenegro': 'unhappy', 'saudi_arabia': 'happy', 'kenya': 'unhappy', 'libya': 'unhappy'}
NYT_Articles_combined['class'] = NYT_Articles_combined['Country'].map(country_class)
NYT_Articles_combined
# Out:
#    Country                                           Snippets    class
# 0    benin  Stephanie Oduro and Franck Chintoya, who met a...  unhappy
# 1    benin  Speaking in Burkina Faso, the French president...  unhappy
# 2    benin  The horrors of a refugee crisis that the world...  unhappy
# 3    benin  “Lead us not into temptation” is not quite rig...  unhappy
# 4    benin  At War existed as a New York Times blog from 2...  unhappy
# 5    benin  Protests calling for the resignation of Presid...  unhappy
# 6    benin  If you are a part of a community like this, on...  unhappy
# 7    benin  There were warning signs. But people typically...  unhappy
# 8    benin  The naturalized citizen, Marcel Pika, moved ba...  unhappy
# 9    benin  Some are hanging on to what they loved about t...  unhappy
# 10   benin  Stephanie Oduro and Franck Chintoya, who met a...  unhappy
# 11   benin  Speaking in Burkina Faso, the French president...  unhappy
# 12   benin  The horrors of a refugee crisis that the world...  unhappy
# 13   benin  “Lead us not into temptation” is not quite rig...  unhappy
# 14   benin  At War existed as a New York Times blog from 2...  unhappy
# 15   benin  Protests calling for the resignation of Presid...  unhappy
# 16   benin  If you are a part of a community like this, on...  unhappy
# 17   benin  There were warning signs. But people typically...  unhappy
# 18   benin  The naturalized citizen, Marcel Pika, moved ba...  unhappy
# 19   benin  Some are hanging on to what they loved about t...  unhappy
# 20   benin  Stephanie Oduro and Franck Chintoya, who met a...  unhappy
# 21   benin  Speaking in Burkina Faso, the French president...  unhappy
# 22   benin  The horrors of a refugee crisis that the world...  unhappy
# 23   benin  “Lead us not into temptation” is not quite rig...  unhappy
# 24   benin  At War existed as a New York Times blog from 2...  unhappy
# 25   benin  Protests calling for the resignation of Presid...  unhappy
# 26   benin  If you are a part of a community like this, on...  unhappy
# 27   benin  There were warning signs. But people typically...  unhappy
# 28   benin  The naturalized citizen, Marcel Pika, moved ba...  unhappy
# 29   benin  Some are hanging on to what they loved about t...  unhappy
# ..     ...                                                ...      ...
# 20   libya  After CNN reported that migrants had been sold...  unhappy
# 21   libya  CNN footage of migrants being auctioned off in...  unhappy
# 22   libya  The group of 162 refugees and migrants had bee...  unhappy
# 23   libya  The gesture could partly reverse the northward...  unhappy
# 24   libya  A half-dozen “precision strikes” hit a trainin...  unhappy
# 25   libya  Absolute dependence on oil and gas has turned ...  unhappy
# 26   libya  For many African migrants trying to reach Euro...  unhappy
# 27   libya  The man is the second suspect to be apprehende...  unhappy
# 28   libya  The British foreign secretary said a group of ...  unhappy
# 29   libya  After receiving a request from Libya to operat...  unhappy
# 30   libya  After CNN reported that migrants had been sold...  unhappy
# 31   libya  CNN footage of migrants being auctioned off in...  unhappy
# 32   libya  The group of 162 refugees and migrants had bee...  unhappy
# 33   libya  The gesture could partly reverse the northward...  unhappy
# 34   libya  A half-dozen “precision strikes” hit a trainin...  unhappy
# 35   libya  Absolute dependence on oil and gas has turned ...  unhappy
# 36   libya  For many African migrants trying to reach Euro...  unhappy
# 37   libya  The man is the second suspect to be apprehende...  unhappy
# 38   libya  The British foreign secretary said a group of ...  unhappy
# 39   libya  After receiving a request from Libya to operat...  unhappy
# 40   libya  After CNN reported that migrants had been sold...  unhappy
# 41   libya  CNN footage of migrants being auctioned off in...  unhappy
# 42   libya  The group of 162 refugees and migrants had bee...  unhappy
# 43   libya  The gesture could partly reverse the northward...  unhappy
# 44   libya  A half-dozen “precision strikes” hit a trainin...  unhappy
# 45   libya  Absolute dependence on oil and gas has turned ...  unhappy
# 46   libya  For many African migrants trying to reach Euro...  unhappy
# 47   libya  The man is the second suspect to be apprehende...  unhappy
# 48   libya  The British foreign secretary said a group of ...  unhappy
# 49   libya  After receiving a request from Libya to operat...  unhappy
#
# [500 rows x 3 columns]

# %%
NYT_Articles_combined.to_csv("Data/NYT Articles/other countries/NYT_Articles_other_Combined.csv")
